# %%
pip install --upgrade openai
# Out:
# ...
#                                               0.0/1.4 MB ? eta -:--:--
#      --------                                 0.3/1.4 MB 5.7 MB/s eta 0:00:01
#      -----------------                        0.6/1.4 MB 6.2 MB/s eta 0:00:01
#      -------------------------                0.9/1.4 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------        1.1/1.4 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 5.8 MB/s eta 0:00:00
# ...
#                                               0.0/199.2 kB ? eta -:--:--
#      ------------------------------------- 199.2/199.2 kB 11.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Сравнение моделей

# %%
import

# %%
import openai

YANDEX_CLOUD_FOLDER = "b1ggusvist6c2sia1dno"
YANDEX_CLOUD_API_KEY = "AQVNw7CdQeUcg4FgFp5bOZU6ojLPTM5FOVGjSiHP"
YANDEX_CLOUD_MODEL = "aliceai-llm/latest"

client = openai.OpenAI(
	api_key=YANDEX_CLOUD_API_KEY,
	base_url="https://ai.api.cloud.yandex.net/v1",
	project=YANDEX_CLOUD_FOLDER
)

response = client.responses.create(
	model=f"gpt://{YANDEX_CLOUD_FOLDER}/{YANDEX_CLOUD_MODEL}",
	temperature=0.3,
	instructions="",
	input="",
	max_output_tokens=500
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[9], line 13
#       9         base_url="https://ai.api.cloud.yandex.net/v1",
#      10         project=YANDEX_CLOUD_FOLDER
#      11 )
#      12
# ---> 13 response = client.responses.create(
#      14         model=f"gpt://{YANDEX_CLOUD_FOLDER}/{YANDEX_CLOUD_MODEL}",
#      15         temperature=0.3,
#      16         instructions="",
#
# ...

# %%
import openai

YANDEX_API_KEY="AQVNw7CdQeUcg4FgFp5bOZU6ojLPTM5FOVGjSiHP"
YANDEX_FOLDER_ID="b1ggusvist6c2sia1dno"

client = openai.OpenAI(
    api_key=YANDEX_API_KEY,
    base_url="https://ai.api.cloud.yandex.net/v1",
    project=YANDEX_FOLDER_ID,
)

models = client.models.list()
print(models.data)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[8], line 12
#       8     base_url="https://ai.api.cloud.yandex.net/v1",
#       9     project=YANDEX_FOLDER_ID,
#      10 )
#      11
# ---> 12 models = client.models.list()
#      13 print(models.data)
#
# File c:\Users\elizz\hackathon_kg\venv\Lib\site-packages\openai\resources\models.py:98, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      84 def list(
#      85     self,
#      86     *,
#    (...)     92     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      93 ) -> SyncPage[Model]:
#      94     """
#      95     Lists the currently available models, and provides basic information about each
#      96     one such as the owner and availability.
#      97     """
# ---> 98     return self._get_api_list(
#      99         "/models",
#     100         page=SyncPage[Model],
# ...

# %%
import openai


client = openai.OpenAI(
    api_key=YANDEX_API_KEY,
    project=YANDEX_FOLDER_ID,
    base_url="https://ai.api.cloud.yandex.net/v1")

# %%
YANDEX_MODEL = "aliceai-llm"

response = client.responses.create(
    model=f"gpt://{YANDEX_FOLDER_ID}/{YANDEX_MODEL}",
    input="Придумай 3 необычные идеи для стартапа в сфере путешествий.",
    temperature=0.8,
    max_output_tokens=1500
)

print(response.output[0].content[0].text)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[4], line 3
#       1 YANDEX_MODEL = "aliceai-llm"
#       2
# ----> 3 response = client.responses.create(
#       4     model=f"gpt://{YANDEX_FOLDER_ID}/{YANDEX_MODEL}",
#       5     input="Придумай 3 необычные идеи для стартапа в сфере путешествий.",
#       6     temperature=0.8,
#
# ...

# %%
models = client.models.list()
print(models.data)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 models = client.models.list()
#       2 print(models.data)
#
# File c:\Users\elizz\hackathon_kg\venv\Lib\site-packages\openai\resources\models.py:98, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      84 def list(
#      85     self,
#      86     *,
#    (...)     92     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      93 ) -> SyncPage[Model]:
#      94     """
#      95     Lists the currently available models, and provides basic information about each
#      96     one such as the owner and availability.
#      97     """
# ---> 98     return self._get_api_list(
#      99         "/models",
#     100         page=SyncPage[Model],
#     101         options=make_request_options(
#     102             extra_headers=extra_headers,
# ...
